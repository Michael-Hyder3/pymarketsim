# %%
from private_values import PrivateValues
# Out:
# Traceback (most recent call last):
#   File "/Users/mkh134/.vscode/extensions/ms-python.python-2025.18.0-darwin-arm64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#   File "<string>", line 1, in <module>
# ModuleNotFoundError: No module named 'private_values'

# %%
p = PrivateValues(q_max=3, val_var=1e6)

# %%
print(p.extra_sell, p.extra_buy)
# Out:
# 643.605712890625 -1507.83740234375

# %%
p.values
# Out:
# tensor([  643.6057,   461.0842,   405.9583,  -512.3292,  -976.6262, -1507.8374])

# %%
p.offset
# Out:
# 3

# %%
p.value_for_exchange(1, -1)
# Out:
# -512.3291625976562

# %%
p.value_for_exchange(1, 1)
# Out:
# -976.6261596679688

# %%
p.value_at_position(-6)
# Out:
# tensor(-3441.4653)

# %%
sum(p.values[0:p.offset]) + p.values[0]*3
# Out:
# tensor(3441.4653)

# %%
p.value_at_position(6)
# Out:
# tensor(-7520.3047)

# %%
sum(p.values[p.offset:]) + p.values[-1]*3
# Out:
# tensor(-7520.3047)

# %%
p.value_at_position(-3)
# Out:
# tensor(-1510.6482)
